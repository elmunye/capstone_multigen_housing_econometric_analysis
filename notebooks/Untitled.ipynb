# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..', 'scripts'))

import numpy as np
import pandas as pd
from core_metrics import ANALYSIS_READY_SCHEMA, run_ols_pipeline

np.random.seed(42)
N = 200
data = {"GEOID": [f"{i}" for i in range(N)],
                "Area_Name": [f"Tract_{i}" for i in range(N)],
                "COUNTY_GEOID": [f"C{i%10:03d}" for i in range(N)],
                "STATEA": [f"{i%5:02d}" for i in range(N)],
                "_total_hh": np.random.randint(100, 5000, N).astype(float)}
# Out:
#   File <string>:16
#     y = 5.0 + 0.03*data["Pct_65Plus"] + 0.05*data["Pct_Hispanic"] + np.random.normal(0, 0.5, N)
#                                                                                                ^
# IndentationError: unindent does not match any outer indentation level

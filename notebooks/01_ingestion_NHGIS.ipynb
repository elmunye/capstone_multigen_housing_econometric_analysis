# %% [markdown]
# # 01 — NHGIS (+ Smart Location) Ingestion
#
# Load NHGIS tract CSVs and EPA Smart Location Database; build **analysis-ready** DataFrame with standardized column names. Output is used by `02_analysis_NHGIS.ipynb` and `03_comparative_master.ipynb`. No SFA; OLS/diagnostics only.

# %%
import os
import sys

REPO_ROOT = os.path.dirname(os.getcwd()) if os.path.basename(os.getcwd()) == "notebooks" else os.getcwd()
sys.path.insert(0, os.path.join(REPO_ROOT, "scripts"))
from ingest_nhgis import build_analysis_ready_nhgis

DATA_DIR = os.path.join(REPO_ROOT, "data")
PROCESSED = os.path.join(REPO_ROOT, "data", "processed")
os.makedirs(PROCESSED, exist_ok=True)

# If raw subfolders exist, use them; else use data/ for nhgis*.csv and SmartLocationDatabase.csv
out_path = os.path.join(PROCESSED, "nhgis_analysis_ready.csv")

# %%
df_nhgis = build_analysis_ready_nhgis(DATA_DIR, out_path=out_path)
print("Shape:", df_nhgis.shape)
print("Saved:", out_path)
# Out:
# /Users/elyas/vscode/capstone_multigen_housing_econometric_analysis/scripts/ingest_nhgis.py:66: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ns["GEOID"] = ns["STATEA"] + ns["COUNTYA"] + ns["TRACTA"]
# /Users/elyas/vscode/capstone_multigen_housing_econometric_analysis/scripts/ingest_nhgis.py:68: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ns["Area_Name"] = ns["NAME_E"]
# ...
